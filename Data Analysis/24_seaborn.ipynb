# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dm_office_sales.csv")
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="salary", y="sales", data= df,hue="level of education", size = "work experience", alpha=0.7, style = "level of education")

# %%
sns.rugplot(x="salary", data=df, height=0.5)

# %%
sns.displot(data=df, x="salary", bins=17, kde=True)

# %%
sns.kdeplot(data=df, x="salary", clip=(40000, 160000), shade=True)

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x="division", hue="level of education")

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = df, x = "level of education", y = "salary", estimator = np.mean)

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.jointplot(x="math score", y="reading score", data = df, kind="hist") #hex, hist, kde shade=true

# %%
sns.jointplot(x="math score", y="reading score", data = df, kind="kde", shade=True)

# %%
sns.jointplot(x="math score", y="reading score", data = df, hue="gender")

# %%
sns.pairplot(data=df, hue="gender", corner=True)

# %%
sns.catplot(x="gender", y="math score", data=df, row="lunch")

# %%
g = sns.PairGrid(df)
g = g.map_upper(sns.scatterplot)
g=g.map_lower(sns.kdeplot)

# %% [markdown]
# # Heatmap

# %%
df = pd.read_csv("country_table.csv")
df = df.set_index("Countries")
df
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# ...

# %%
sns.heatmap(df.drop("Life expectancy", axis=1), lw=2, annot=True, cmap="viridis")

# %%
sns.clustermap(df.drop("Life expectancy", axis=1), lw=2, annot=True, cmap="viridis", col_cluster=False)
