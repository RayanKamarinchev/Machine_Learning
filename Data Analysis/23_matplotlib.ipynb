# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,10)
y= 2*x
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.xlim(0,6)
plt.ylim(0,15)
plt.title("cool title")
plt.savefig("myfirstplot.jpg")

# %%
import math

a = np.linspace(0,10,11)
b = a**5
x= np.arange(0,10)
y=x*2

def plot_derrivitives(b, step):
  res = b/a*step
  axes.plot(a,res, label = "^" + str(n), lw=max(step/2,1), ls="--")
  return res

fig = plt.figure(figsize = (3,5), dpi=100)
axes = fig.add_axes([0,0,1,1])

n = 5
axes.plot(a,b, label = "^"+str(n), color="#0094aa", lw=2.5, ls="-.")
axes.plot(a,a*10000, label = "linear", marker="o", ms=10)
for i in range(5,1,-1):
  n-=1
  b = plot_derrivitives(b,n)

axes.set_title("Derivatives")

plt.legend(loc="upper left")
plt.savefig("derivatives.jpg", bbox_inches="tight")
# Out:
# <ipython-input-97-425b23b7cd7a>:9: RuntimeWarning: invalid value encountered in true_divide
#   res = b/a*step
